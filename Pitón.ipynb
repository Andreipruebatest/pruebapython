# %% [markdown]
# <a href="https://colab.research.google.com/github/Andreipruebatest/pruebapython/blob/main/Pit%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python

# %%
#version de python
# !python --version
# Out:
# Python 3.8.10

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#cuaderno de jupiter
lenguaje = 'Python'

# %%
print(lenguaje)
# Out:
# Python

# %%
lenguaje
# Out:
# 'Python'

# %%
def ejemplo():
  return 3

# %%
ejemplo()
# Out:
# 3

# %%
lenguaje = 'Python'
print(lenguaje)
def ejemplo2():
  return 32
ejemplo2()
# Out:
# Python
# 32

# %%
from PIL import Image
im = Image.open('foto.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1000 at 0x7FA99BC47610>
